# %% [markdown]
# # Project

# %%
import osmnx as ox
import networkx as nx
import geopandas as gpd
import pandas as pd

# %%
waqi_2015H1 = pd.read_csv('waqi-covid-2015H1.csv',sep=',', error_bad_lines=False, header=None)

# %%
waqi_2015H1 = pd.read_csv('waqi-covid-2015H1.csv',sep=',', error_bad_lines=False)
waqi_2016H1 = pd.read_csv('waqi-covid-2016H1.csv',sep=',', error_bad_lines=False)
waqi_2017H1 = pd.read_csv('waqi-covid-2017H1.csv',sep=',', error_bad_lines=False)
waqi_2018H1 = pd.read_csv('waqi-covid-2018H1.csv',sep=',', error_bad_lines=False)
waqi_2019Q1 = pd.read_csv('waqi-covid-2019Q1.csv',sep=',', error_bad_lines=False)
waqi_2019Q2 = pd.read_csv('waqi-covid-2019Q2.csv',sep=',', error_bad_lines=False)
waqi_2019Q3 = pd.read_csv('waqi-covid-2019Q3.csv',sep=',', error_bad_lines=False)
waqi_2019Q4 = pd.read_csv('waqi-covid-2019Q4.csv',sep=',', error_bad_lines=False)
waqi_2020 = pd.read_csv('waqi-covid-2020.csv',sep=',', error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-29b16d83dbb5> in <module>
# ----> 1 waqi_2015H1 = pd.read_csv('waqi-covid-2015H1.csv',sep=',', error_bad_lines=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
place = 'Barcelona, Spain'
city = ox.gdf_from_place(place)
ox.plot_shape(ox.project_gdf(city))
# Out:
# /Users/davidecallegaro/anaconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# (<Figure size 432x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fcbd120cd10>)

# %%
graph = ox.graph_from_place('Barcelona, Spain', network_type=’drive’)
nodes, streets = ox.graph_to_gdfs(graph)streets.head()
# Out:
#   File "<ipython-input-8-4f7bbe39bf7c>", line 1
#     graph = ox.graph_from_place('Barcelona, Spain', network_type=’drive’)
#                                                                        ^
# SyntaxError: invalid character in identifier

# %%
nodes, streets = ox.graph_to_gdfs(graph)
G = nx.read_gml('A.ES.SDGC.CP.07002.cadastralparcel.gml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-736c6fb1674d> in <module>
# ----> 1 nodes, streets = ox.graph_to_gdfs(graph)
#       2 G = nx.read_gml('A.ES.SDGC.CP.07002.cadastralparcel.gml')
#
# NameError: name 'graph' is not defined
